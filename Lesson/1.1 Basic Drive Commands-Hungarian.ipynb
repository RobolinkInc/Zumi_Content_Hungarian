# %% [markdown]
# <img src="../Data/images/ZumiHeader.png" width=700>

# %% [markdown]
# # Alap Vezetési Parancsok
#
# <font size =3>Üdvözlünk Zümi első óráján! 🎉 Mielőtt elkezdenéd a gépi tanulást Zümivel, segítened kell neki abban, hogy megtanulja, hogyan haladjon előre, hátra, balra és jobbra. Ebben a leckében később megtanulhatod, hogyan készíts egyedi távirányítót.</font>
#
#
# ### Könyvtárak importálása
# <font size =3>A Zümi bármilyen kóddal történő futtatásának első lépése a könyvtárak importálása lesz. Ez a cella importálja a Zümi összes szükséges funkcióját, például a meghajtóparancsokat, a kamerát vagy a képernyőt. Ha nem futtatod ezt a cellát, akkor a program többi része nem fog működni. Ehhez csak a következő cellát kell *egyszer* futtatnod minden leckében, hacsak nem indítod újra a Jupyter Notebookot.</font>

# %%
from zumi.zumi import Zumi
import time

zumi = Zumi()

# %% [markdown]
# ## Meghajtóparancsok
#
# <font size =3> Zümi különböző függvényeket használ a vezetéshez. Ebben a leckében részletesebben elmagyarázzuk, milyen függvények vannak, mit csinálnak, és hogyan használhatod őket a távirányítód létrehozásához. </font>
#
#
# ### Mik a függvények?
# <font size =3> Ahhoz, hogy a Zümi elinduljon, néhány **függvényt** kell használnunk. Gondolj úgy a függvényekre, mint egy kódcsomagokra, amelyek segítségével hatékonyabbá teheted a programod. Lehetnek **bemenetei** és **kimenetei**.</font>
# <img src="../Data/images/function.jpg" width=700>
#
# ### Zümi függvényei
# <font size=3>Az alábbiakban felsoroljuk az alapvető hajtásfunkciókat:
#
# * <font face="Courier">forward()</font>: Elindul előre 40-es sebességgel 1 másodpercig abba az irányba, amerre Zümi néz
# * <font face="Courier">reverse()</font>: Elindul hátra 40-es sebességgel 1 másodpercig abból az irányból, amerről Zümi néz
# * <font face="Courier">turn_left()</font>: 90 fokkal balra fordul
# * <font face="Courier">turn_right()</font>: 90 fokkal jobbra fordul
#
# </font>
#
# ### Hogyan kezdjük a függvényeket?
# <font size =3> A számítástechnikában valaki felszólítása, alapvetően a futtatását jelenti. A függvényeket a tárgy nevével kell elnevezni, amely jelen esetben a <font face="Courier">Zümi</font>.
#
# <img src="../Data/images/zumi_forward.jpg" width=700>
#
# Az alábbi cellában van egy példa a <font face="Courier">forward()</font> függvényre. A Zümi egy másodpercig halad majd előre, ezért ügyelj arra, hogy elegendő hely álljon rendelkezésére a területen! </font>

# %%
zumi.forward()

# %% [markdown]
# <font size =3>  Most próbáljuk meg hátra... </font>

# %%
# ITT Írj egy kódot, hogy Zümi 1 másodpercig hátrafelé haladjon

# %% [markdown]
# <font size=3>Nézzük át a következő két függvényt. A <font face="Courier">turn_left()</font> és <font face="Courier">turn_right()</font> felszólítás Zümi balra vagy jobbra kanyarodásához vezet.
#
# Teszteld ezt a kódot lent, majd adj hozzá további parancsokat bármilyen sorrendben, hogy lásd, mikor mi történik. Ha szeretnél egy kis időt az egyes parancsok között, adj meg egy <font face="Courier">time.sleep(seconds)</font>  parancsot, hogy a programot a megadott másodpercekig késleltesse.
# Futtasd az alábbi kódot, hogy lásd, hogyan működik, majd próbálj meg hozzáadni még néhány parancsot a kódhoz. </font>

# %%
zumi.forward() # Menjen előre 1 másodpercig, majd álljon meg
time.sleep(2) # Várjon 2 másodpercet
zumi.turn_right() # Forduljon jobbra 90 fokot
# Adj hozzá még néhány kódot!

# %% [markdown]
# ### Paraméterek
# <font size =3> Ezen a ponton érdemes lehet megváltoztatni az időtartamot, irányt és sebességet, amiben Zümi előremegy. Egyes funkciók lehetővé teszik **paraméterek** megadását, amik további információként szólgálnak, és lehetővé teszik a függvény további igény szerinti testreszabását. Jelenleg a <font face="Courier">forward()</font> az alapértelmezett sebességben, időtartamban és irányban fog történni, de a paraméterek megváltoztatásával megváltoztathatod a Zümi sebességét, valamint hogy mennyi ideig haladjon egy bizonyos irányban.
#
# Át fogjuk ugrani a Zümi irányának megváltoztatását, mivel ehhez még először meg kell érteni a Zümi érzékelőit, de a sebességet és az időtartamot megváltoztathatod, ha meghatározod őket a függvény belsejében. Az alábbi cellában a kód módosult úgy, hogy a sebességet 30-ra csökkentettük, és 2 másodpercig haladjon. Előtte nézd meg, hogy van-e elég helyed! </font>

# %%
zumi.forward(speed=30, duration=2)

# %% [markdown]
# <font size =3> Ugyanezt megteheted hátramenetben is. Változtasd meg a sebességet és az időtartamot a <font face="Courier">reverse()</font>függvényben is: </font>

# %%
# ITT Módosítsd a hátramenetet, hogy 3 másodpercig 20-as sebességgel haladjon

# %% [markdown]
# ### Fokok
#
# <font size=3>A <font face="Courier">turn_left()</font> és <font face="Courier">turn_right()</font> függvényeknek is vannak paraméterei, amelyeket meg lehet változtatni. Az alapértelmezett érték 90 fok, de ez az érték is megváltoztatható.
#
# Az alábbi kód szerint Zümi 90 fok helyett 45 fokkal fordul jobbra:</font>

# %%
zumi.turn_right(45)

# %% [markdown]
# <font size=3> Próbáld ki a fordulások pontosságát különböző szögek tesztelésével. Használd ezt a diagramot referenciaként, ha szükséged van rá! Zümi nem tökéletes, így a tényleges szög, amelyre Zümi beáll, egy vagy két fokkal eltérhet.</font>
#
# <img src="../Data/images/zumi_angle.jpg" width=700>
#
# <font size=3>**Megjegyzés**: Van egy másik rejtett alapértelmezett paraméter a <font face="Courier">turn_right()</font> és <font face="Courier">turn_left()</font>függvényben. Amikor a <font face="Courier">turn_left(45)</font> függvényt írod, igazából a <font face="Courier">turn_left(desired_angle=45, duration=1)</font> függvényt kapod. Az időtartam határozza meg, hogy Zümi mennyi idő alatt teljesítse az adott fordulatot. Egy másodperc elegendő idő kisebb fordulatokhoz, de mi lenne, ha 135 fokkal szeretnéd, hogy forduljon? Növelni kell az időt is, amelyre Züminek a forduláshoz szüksége van.
#
# <font face="Courier">zumi.turn_left(120, 1.5)</font>
#
# Mivel Zümi 120 fokkal fordul, növelned kell az időtartamot, különben Zümi nem lesz képes befejezni a fordulást. Lehet, hogy módosítanod kell a második paramétert, mert minden Zümi egyedi. Az alábbi cellával kísérletezhetsz a vezetéssel és a fordulatokkal. </font>

# %%
# Itt tudsz tesztelni

# %% [markdown]
# ## Újrakalibrálás
# <font size=3> Ha úgy véled, hogy a Zümi nem megy egyenesen, akkor lehet, hogy újra kell kalibrálnod. Ez akkor fordulhat elő, ha Zümi elkezd túlmelegedni. Ne vedd fel Zümit, és győződj meg róla, hogy sima felületen van. </font>

# %%
zumi.mpu.calibrate_MPU()

# %% [markdown]
# <font size=3> Most már tudod az alapokat! A lenti cellában tesztelhetsz még néhány kódot. További kihívásként használj néhány körülötted lévő tárgyat egy egyszerű akadálypálya felépítéséhez, és írj be egy kódot, amellyel Zümi átmegy rajta, anélkül, hogy bármibe is beleütközne. A következő leckében megtanulhatod, hogyan kombináld a meghajtó parancsokat az *if* utasításokkal saját távirányítód létrehozásához. </font>

# %%
# Írj ide még néhány kódot!

# %% [markdown]
# <hr>
#
# # Extra Feladatok <br>
#
# <img src="../Data/images/engineering_extension.png" width=75 align="left">
#
# ###  Híd Kihívás <br> <br>
# <font size=3> Építs hidat az általad választott tárgyból. Ennek a tárgynak azonban laposnak és viszonylag szélesnek kell lennie, hogy Zümi kerekei ne akadjanak el. Jégkrém pálcák jók lehetnek. Használhatók olyan korlátozások, mint a dőlésszög mértéke, magassága, szélessége és a jégkrém pálcikák száma. A híd megépítése után ellenőrizd, hogy <br>a) Zümi képes-e átkelni rajta <br>és / vagy <br>b) a híd képes-e elbírni Zümi súlyát.<br>Egy extra kihívás érdekében további súly is hozzáadható Zümihez.</font>
#
# <img src="../Data/images/math_extension.jpg" width=70 align="left">
#
# ### Sebesség kiszámítása <br> <br>
# <font size=3> Vezesd a Zümit egy bizonyos távolságra vagy bizonyos ideig, miközben a másik paramétert méred. Ezután használd a d=rt egyenletet az haladási sebesség megfejtéséhez. Ezt követően ábrázold és elemezd az eredményeket.
# A fizika beépítéséhez adj hozzá súlyt a Zümihez. Hogyan befolyásolja ez Zümi paramétereit?</font>
