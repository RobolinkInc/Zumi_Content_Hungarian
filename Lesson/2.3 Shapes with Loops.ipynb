# %% [markdown]
# <img src="../Data/images/ZumiHeader.png" width=700>

# %% [markdown]
# # Alakzatok ismétlődő parancssorral
#
# <font size =3> Bizonyos alakzatoknak meghatározott számú foka van, amelyet a belső szögek adnak össze. Például egy négyzet szöge 360​​°, míg egy háromszög szöge 180°. Megtanulod, hogy azokhoz az alakzatokhoz, amelyeknek azonos hosszúságú oldalai vannak, hogyan lehet hatékonyabb kódot írni egy ismétlődő parancssorral.</font>
#
# <img src="../Data/images/shapes.png">

# %% [markdown]
# ## Bevezetés
# <font size=3> Soha ne felejtsd el, hogy importálni kell a könyvtárat</font>
#
# ### Könyvtárak importálása

# %%
from zumi.zumi import Zumi
import time

zumi = Zumi()

# %% [markdown]
# ### Négyzet kódja
# <font size =3> A for ismétlődő parancssor értékének felméréséhez először gondolj a négyzetben való vezetés kódjára. Mivel egy négyzetnek négy egyenlő oldala van, ezért előre kell mennie, majd négyszer jobbra vagy balra fordulnia.</font>
#
# <img src="../Data/images/square.png" width=200>
#
# <font size =3>Írj egy egyszerű négyzetkódot az 1.1 lecke meghajtóparancsaival.</font>

# %%
# Írj ide egy négyzet kódot.

# %% [markdown]
# ## Ismétlődő parancssorok
# <font size =3> Valószínűleg észrevetted, hogy ugyanazt a kódrészt négyszer is meg kellett ismételned. Ez sok gépeléssel jár! Ennek elkerüléséhez használhatsz egy ismétlődő parancssort, amely lehetővé teszi a kód egyes részeinek megismétlését. Nagyszerű parancsikonok --- nélkülük mindig ugyanazokat a sorokat kellene leírnod újra és újra. Ismétlődő parancssornak hívják őket, mert az utolsó utasítás után a parancs visszakanyarodik az elejére.</font>
#
# <img src="../Data/images/loop_square.png" width=300>
#
# ### For ismétlődő parancssorok
# <font size =3> A for ismétlődő parancssor annyiszor ismétlődik, ahányszor be van programozva. Ez azt jelenti, hogy kiválaszthatod, hányszor ismételje meg önmagát a kód. Itt ugyanaz a négyzetkód van megírva, mint egy ismétlődő parancssor a Pythonban. Mit veszel észre?<br><br>
#
# <font face="Courier">
# for x in range(4): <br>
# <span style="margin-left: 40px;">zumi.forward()</span> <br>
# <span style="margin-left: 40px;">zumi.turn_left()</span> <br>
# </font>
#
#  Ebben a példában x egy **változó** vagy helyőrző annak nyomon követésére, hogy az ismétlődő parancssor hányszor futott. Szerinted melyik számnál kezdődik az ismétlődő parancssor? Futtasd az alábbi cellát, és számold meg a kimeneteket. A kimeneteket egy másodperces késleltetéssel választottuk el, hogy megkönnyítsük a számlálást. Nézd meg, hogyan írja ki az ismétlődő parancssor az x értéket, a változónkat, ahogy az **ismétlési szerkezet** eggyel növekszik. </font>

# %%
for number in range(4):
    print(number)
    time.sleep(1)

# %% [markdown]
# <font size =3> Láttad, hogy a változó 0-ról indul és 3-ra végződik? A Pythonban a ciklusok 0-val kezdődnek és 1-gyel növekszenek alapértelmezés szerint. A program elején x=0. A program végére x=3. A változó 3-nál áll meg, mert az ismétlődő parancssor addig folytatódik, amíg x kisebb, mint a zárójelben szereplő érték. Ha még egyet adunk háromhoz, x=4. A 4 nem kevesebb, mint 4, így az ismétlődő parancssor leáll. Próbáld meg megváltoztatni a zárójelben lévő értéket az ismétlési szerkezet számának szabályozásához. Milyen számnál áll meg?
#
# Az alábbi cellában gyakorold az ismétlődő parancssorokat úgy, hogy négy **jobbra** fordulatot tesz a balra fordulatok helyett. </font>

# %%
# Használj ismétlődő parancssort a saját négyzeted kódolásához!

# %% [markdown]
# ## Több alakzat
#
# <font size=3> Milyen más alakzatokat készíthetsz ismétlődő parancssorral? A négyzet a legkönnyebb, mert minden fordulat 90 fokos, de mi van a többi formával? Hány oldala van egy háromszögnek? Ez a háromszög **egyenlő oldalú** háromszög lesz, ami azt jelenti, hogy mindhárom oldal azonos hosszúságú és minden szög azonos méretű fokkal rendelkezik.
# Íme egy tipp: az összes **szabályos** sokszög vagy egyforma oldalú alakzat külső szöge mindig 360 fokot tesz ki. <br>
#
# <img src="../Data/images/square_vs_triangle.png" width=700>

# %%
# Írd ide a háromszög kódját!

# %% [markdown]
# <font size =3> Sok más alakzatra is megtaníthatod Zümit. Próbálj ki ötszöget, hatszöget vagy nyolcszöget! Szükséged lehet ceruzára és papírra, hogy kitaláld, hány fokot kell elfordítanod. Ne feledd, hogy a fokok számának és az oldalak számának szorzatának meg kell egyeznie 360 ​​fokkal. </font>
#
# <img src="../Data/images/shapes2.jpg" width=700>

# %%
# Kódolj ötszöget

# %%
# Kódolj hatszöget

# %%
# Kódolj nyolcszöget

# %% [markdown]
# <hr>
#
# # Extra Tevékenységek <br>
#
# <img src="../Data/images/math_extension.jpg" width=70 align="left">
#
# ### Kerületek és területek<br> <br>
# <font size=3>Használj szalagot vagy egy nagyméretű szőnyeget a koordinátasík tervezéséhez a padlón. Jelöld meg, amikor a Zümi megáll és fordul, az alakzat pontjainak meghatározásához. Ezután mérd meg az alakzat oldalainak hosszát, és találd ki az alakzat kerületét és területét.</font>
#
#
# <img src="../Data/images/math_extension.jpg" width=70 align="left">
#
# ### Áthelyezés <br> <br>
# <font size=3> Minden alakzathoz, amit programozol, programozz be az eredeti alakzat forgatását, tükrözését vagy áthelyezését.<br> <br>
# A **forgatás** azt jelenti, hogy az alakzat egy központi pont körül fordul.<br>
# A **tükrözés** azt jelenti, hogy az alakzat átfordul egy vonalon.<br>
# Az **áthelyezés** azt jelenti, hogy az alakzat minden pontja azonos távolságra, ugyanabban az irányban mozog.<br> <br>
#
# Mindhárom esetben az alakzatnak továbbra is ugyanaz a mérete, területe, szöge és oldalhossza. </font>
